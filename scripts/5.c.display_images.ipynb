# %%
from pathlib import Path
from IPython.display import Image, display

base = Path(r"C:\Users\souma\projects\wiki_rag\data\demo_images")

image_paths = [
    base / "pexels-jvdm-1524628.jpg",
    base / "pexels-nicolette-villavicencio-1114434-5940098.jpg",
    base / "pexels-richard-verbeek-177679-572861.jpg",
]

for path in image_paths:
    display(Image(filename=str(path), width=300))
